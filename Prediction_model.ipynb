# %%
# Load model and Scaler

# %%
import joblib
import pandas as pd

model = joblib.load('final_random_forest_model.pkl')
scaler = joblib.load('scaler.pkl')

# %%
# Load data

# %%
df = pd.read_csv('data/processed/model_employee_data.csv')

# %%
# prepare input and predict

# %%
X = df.drop('PerformanceRating', axis=1)
X_scaled = scaler.transform(X)

predictions = model.predict(X_scaled)

# %%
# Create prediction DataFrame

# %%
pred_df = df.copy()
pred_df['PredictedPerformanceRating'] = predictions

# %%
# print samples and prediction

# %%
pred_df.head(10)
# Out:
#    EmpNumber  Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 0          0   32       1                    2              2              5
# 1          1   47       1                    2              2              5
# 2          2   40       1                    1              1              5
# 3          3   41       1                    0              0              3
# 4          4   60       1                    2              2              5
# 5          5   27       1                    1              0              1
# 6          6   50       1                    2              1              5
# 7          7   28       0                    1              2              1
# 8          8   36       0                    1              1              1
# 9          9   38       0                    1              2              1
#
#    EmpJobRole  BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# ...

# %%
# printing distributions

# %%
pred_df['PredictedPerformanceRating'].value_counts()
# Out:
# PredictedPerformanceRating
# 3    887
# 2    186
# 4    127
# Name: count, dtype: int64

# %%
# Employee ID + Prediction

# %%
pred_df[['EmpNumber', 'PredictedPerformanceRating']].head(10)
# Out:
#    EmpNumber  PredictedPerformanceRating
# 0          0                           3
# 1          1                           3
# 2          2                           4
# 3          3                           3
# 4          4                           3
# 5          5                           4
# 6          6                           3
# 7          7                           3
# 8          8                           3
# 9          9                           3

# %% [markdown]
# ## Note
#
# __The final trained Random Forest model was successfully used to generate employee performance predictions on processed data, demonstrating effective model deployment.__
